# %%
import os
from tqdm import tqdm
from itertools import chain
import pandas as pd
import numpy as np
import random, torch
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = 'white', font_scale=1.5)
# %matplotlib inline

# %% [markdown]
# ## 1. Importing Compass
# #### Installation
# Install immuno-compass via pip:
# ```bash
# conda create -n compass python=3.12
# conda activate compass
# pip install immuno-compass
# ```

# %%
import sys
sys.path.insert(0, '/mnt/shenwanxiang/Research/COMPASS_main/')

# %%
from compass import PreTrainer, FineTuner, loadcompass

# %% [markdown]
# ## 2. Making Predictions with a Compass Model

# %% [markdown]
# You can download all available Compass fine-tuned models [here](https://www.immuno-compass.com/download/) for prediction.
#
# The input `df_tpm` is gene expression tabular data. Please refer [here](https://www.immuno-compass.com/help/index.html#section1) for details on generating input data. The first column represents the cancer code, while the remaining 15,672 columns correspond to genes. Each row represents one patient. An example input file can be downloaded [here](https://www.immuno-compass.com/download/other/compass_gide_tpm.tsv).
#
# The output `df_pred` contains two columns, where `0` indicates non-response and `1` indicates response.

# %%
df_tpm = pd.read_csv('./data/compass_gide_tpm.tsv', sep='\t', index_col=0)
#download a compass model from https://www.immuno-compass.com/download/model/LOCO/pft_leave_Gide.pt 
model = loadcompass('./model/pft_leave_Gide.pt', map_location = 'cpu')
# Use map_location = 'cpu' if you dont have a GPU card
_, df_pred = model.predict(df_tpm, batch_size=128)
# Out:
# 100%|###################################################################################| 1/1 [00:03<00:00,  3.88s/it]

# %%
df_pred.head()
# Out:
#                      0         1
# Index
# 1_ipiPD1_PRE  0.429565  0.570435
# 2_ipiPD1_PRE  0.999955  0.000045
# 6_ipiPD1_PRE  0.224929  0.775071
# 7_ipiPD1_PRE  0.004783  0.995217
# 8_ipiPD1_PRE  0.841231  0.158769

# %% [markdown]
# ## 3. Extracting Features with a Compass Model
#
# Both pre-trained (PT) and fine-tuned (FT) Compass models can function as feature extractors. The extracted gene-level, geneset-level, or cell type/pathway-level features can be used to build a logistic regression model for response prediction or a Cox regression model for survival prediction.

# %%
# Use any Compass model of your choice
model = loadcompass('./model/pretrainer.pt') 
#downloaded from https://www.immuno-compass.com/download/model/pretrainer.pt 
dfgn, dfgs, dfct = model.extract(df_tpm, batch_size=128, with_gene_level=True)
dfct.head()
# Out:
# 100%|###################################################################################| 1/1 [00:00<00:00,  1.45it/s]
#                 CANCER  Bcell_general  Memory_Bcell  Naive_Bcell  Plasma_cell  \
# Index
# 1_ipiPD1_PRE -0.757586      -0.262867      0.129370    -0.815162     0.278603
# 2_ipiPD1_PRE -0.757746      -0.353675      0.393750    -0.811435     0.074256
# 6_ipiPD1_PRE -0.757299      -0.372067      0.161556    -0.798404     0.103220
# 7_ipiPD1_PRE -0.757101      -0.242434      0.178155    -0.803801     0.206927
# 8_ipiPD1_PRE -0.758030      -0.396814      0.197401    -0.809641     0.081464
#
#               CD4_Tcell  CD8_Tcell  Memory_Tcell  Naive_Tcell  Tcell_general  \
# Index
# 1_ipiPD1_PRE  -0.169692  -0.026435      0.039869    -0.401233      -0.215705
# 2_ipiPD1_PRE  -0.185324  -0.012123      0.077559     0.536754      -0.107892
# 6_ipiPD1_PRE  -0.161113   0.021997      0.145440     0.043221      -0.112898
# 7_ipiPD1_PRE  -0.183297   0.033455      0.059158    -0.426837      -0.106407
# 8_ipiPD1_PRE  -0.181386   0.056288      0.205692    -0.000701      -0.137546
#
#               ...  Pancreatic  Pneumocyte  Apoptosis_pathway  IFNg_pathway  \
# Index         ...
# 1_ipiPD1_PRE  ...    0.099943   -0.063546           0.120870     -0.268174
# 2_ipiPD1_PRE  ...    0.080122    0.034633           0.113858     -0.265196
# 6_ipiPD1_PRE  ...    0.070483   -0.081517           0.147193     -0.191045
# 7_ipiPD1_PRE  ...    0.026826   -0.105330           0.239903     -0.129926
# 8_ipiPD1_PRE  ...    0.151547   -0.056724           0.052763     -0.204880
#
#               TGFb_pathway  Cytokine  Cell_proliferation       TLS  \
# Index
# 1_ipiPD1_PRE     -0.081784 -0.072616           -0.136177 -0.176708
# 2_ipiPD1_PRE      0.024003 -0.092963           -0.140686 -0.014389
# 6_ipiPD1_PRE     -0.072711 -0.065004           -0.167961 -0.164095
# 7_ipiPD1_PRE     -0.094376 -0.052420           -0.149514 -0.147732
# 8_ipiPD1_PRE     -0.098621 -0.074825           -0.063258 -0.099110
#
#               Genome_integrity  Reference
# Index
# 1_ipiPD1_PRE          0.152991   0.453108
# 2_ipiPD1_PRE          0.203304   0.457289
# 6_ipiPD1_PRE          0.135996   0.448622
# 7_ipiPD1_PRE          0.146455   0.431817
# 8_ipiPD1_PRE          0.141699   0.468105
#
# [5 rows x 44 columns]

# %% [markdown]
# The outputs `dfgn`, `dfgs`, and `dfct` correspond to gene-level (15,672), geneset-level (133), and concept-level (44) features, respectively. The extracted features are scalar scores. If you need vector features (dim=32), use the following method:

# %%
dfgs, dfct = model.project(df_tpm, batch_size=128)
dfct.head()
# Out:
# 100%|###################################################################################| 1/1 [00:00<00:00,  1.98it/s]
#                              channel_0  channel_1  channel_2  channel_3  \
# 1_ipiPD1_PRE$$Bcell_general  -0.034739  -0.332635  -0.642141   0.561939
# 1_ipiPD1_PRE$$Memory_Bcell   -0.022590  -0.397354  -0.868363   1.010871
# 1_ipiPD1_PRE$$Naive_Bcell     0.107904  -0.501725  -0.788940   0.905886
# 1_ipiPD1_PRE$$Plasma_cell     0.218896  -0.407893  -0.895497   0.977370
# 1_ipiPD1_PRE$$CD4_Tcell       0.093407  -0.404865  -0.768114   0.946871
#
#                              channel_4  channel_5  channel_6  channel_7  \
# 1_ipiPD1_PRE$$Bcell_general   0.020290   0.367835   0.518909   0.365392
# 1_ipiPD1_PRE$$Memory_Bcell   -0.118244   0.678905   0.769296   0.625515
# 1_ipiPD1_PRE$$Naive_Bcell    -0.090654   0.603379   0.865653   0.840186
# 1_ipiPD1_PRE$$Plasma_cell    -0.078406   0.657787   0.624934   0.675836
# 1_ipiPD1_PRE$$CD4_Tcell       0.021003   0.491076   0.790252   0.711688
#
#                              channel_8  channel_9  ...  channel_22  \
# 1_ipiPD1_PRE$$Bcell_general   0.175236  -0.415692  ...   -0.021645
# 1_ipiPD1_PRE$$Memory_Bcell    0.419354  -0.524081  ...    0.130836
# 1_ipiPD1_PRE$$Naive_Bcell     0.485864  -0.464720  ...    0.155620
# 1_ipiPD1_PRE$$Plasma_cell     0.520595  -0.495843  ...    0.155416
# 1_ipiPD1_PRE$$CD4_Tcell       0.260992  -0.424142  ...    0.110076
#
#                              channel_23  channel_24  channel_25  channel_26  \
# 1_ipiPD1_PRE$$Bcell_general   -0.236544   -0.747826    0.391741   -1.088722
# 1_ipiPD1_PRE$$Memory_Bcell    -0.081616   -0.792151    0.098789   -0.996874
# 1_ipiPD1_PRE$$Naive_Bcell      0.130635   -0.838648    0.262417   -0.950026
# 1_ipiPD1_PRE$$Plasma_cell     -0.208327   -0.602620    0.115889   -1.072236
# 1_ipiPD1_PRE$$CD4_Tcell       -0.188954   -0.752739    0.272066   -0.948871
#
#                              channel_27  channel_28  channel_29  channel_30  \
# 1_ipiPD1_PRE$$Bcell_general    0.756434    0.211727   -0.244743    0.848020
# 1_ipiPD1_PRE$$Memory_Bcell     0.424624    0.028835    0.097752    1.040196
# 1_ipiPD1_PRE$$Naive_Bcell      0.437575   -0.043248   -0.035564    0.939187
# 1_ipiPD1_PRE$$Plasma_cell      0.395798   -0.030286   -0.012423    1.086152
# 1_ipiPD1_PRE$$CD4_Tcell        0.518185    0.120522   -0.022940    0.828513
#
#                              channel_31
# 1_ipiPD1_PRE$$Bcell_general    0.388430
# 1_ipiPD1_PRE$$Memory_Bcell     0.372795
# 1_ipiPD1_PRE$$Naive_Bcell      0.296764
# 1_ipiPD1_PRE$$Plasma_cell      0.323278
# 1_ipiPD1_PRE$$CD4_Tcell        0.329999
#
# [5 rows x 32 columns]

# %% [markdown]
# ## 4. Fine-Tuning Compass on Your Own Data
#
# If you have in-house data and would like to fine-tune a Compass model, you can use any Compass model for fine-tuning. You can either load the pre-trained Compass model or a publicly available fine-tuned Compass model.
#
# **Important Note:** If you choose a fine-tuned model for further fine-tune (multi-stage FT), ensure that the `load_decoder` parameter in `ft_args` is set to `True`:
# ```python
# ft_args = {'load_decoder': True}
# ```

# %%
### Example Fine-Tuning Process
model = loadcompass('./model/finetuner_pft_all.pt')  
ft_args = {'mode': 'PFT', 'lr': 1e-3, 'batch_size': 16, 'max_epochs': 100, 'verbose':0, 'load_decoder': True}
finetuner = FineTuner(model, **ft_args)

# Load the true labels
df_cln = pd.read_csv('./data/compass_gide_clinical.tsv', sep='\t', index_col=0)
dfy = pd.get_dummies(df_cln.response_label)

# Fine-tune the model
finetuner.tune(df_tpm, dfy)
finetuner.save('./model/my_finetuner.pt')
# Out:
#  19%|###############2                                                                | 19/100 [00:29<02:04,  1.53s/it]
# Stopping early at epoch 20. Meet minimal requirements by: f1=0.92,mcc=0.81,prc=0.96, roc=0.95
# Saving the model to ./model/my_finetuner.pt

# %%
finetuner.model
# Out:
# Compass(
#   (inputencoder): TransformerEncoder(
#     (cancer_token_embedder): Embedding(33, 32)
#     (gene_token_embedder): GeneEmbedding(
#       (abundance_embedder): AbundanceEmbedding(
#         (layers): Sequential(
#           (0): _GeneExpressionEmbedding()
#           (1): ReLU()
#         )
#       )
#     )
#     (encoder): Encoder(
#       (layers): ModuleList(
#         (0): PerformerLayer(
#           (self_attn): PerformerAttention(
#             (fast_attention): FastAttention(
#               (kernel_fn): ReLU()
#             )
#             (to_q): Linear(in_features=32, out_features=64, bias=False)
#             (to_k): Linear(in_features=32, out_features=64, bias=False)
#             (to_v): Linear(in_features=32, out_features=64, bias=False)
#             (to_out): Linear(in_features=64, out_features=32, bias=True)
#             (dropout): Dropout(p=0.2, inplace=False)
#           )
#           (_ff_block): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.2, inplace=False)
#             (3): Linear(in_features=64, out_features=32, bias=True)
#             (4): Dropout(p=0.2, inplace=False)
#           )
#           (dropout1): Dropout(p=0.2, inplace=False)
#           (norm1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (latentprojector): DisentangledProjector(
#     (genesetprojector): GeneSetProjector(
#       (geneset_aggregator): GeneSetAggregator(
#         (aggregator): GeneSetAttentionAggregator(
#           (attention_weights): ParameterDict(
#               (geneset_0): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#               (geneset_1): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_10): Parameter containing: [torch.cuda.FloatTensor of size 19x1 (GPU 0)]
#               (geneset_100): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_101): Parameter containing: [torch.cuda.FloatTensor of size 17x1 (GPU 0)]
#               (geneset_102): Parameter containing: [torch.cuda.FloatTensor of size 10x1 (GPU 0)]
#               (geneset_103): Parameter containing: [torch.cuda.FloatTensor of size 17x1 (GPU 0)]
#               (geneset_104): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#               (geneset_105): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_106): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_107): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (geneset_108): Parameter containing: [torch.cuda.FloatTensor of size 15x1 (GPU 0)]
#               (geneset_109): Parameter containing: [torch.cuda.FloatTensor of size 40x1 (GPU 0)]
#               (geneset_11): Parameter containing: [torch.cuda.FloatTensor of size 37x1 (GPU 0)]
#               (geneset_110): Parameter containing: [torch.cuda.FloatTensor of size 16x1 (GPU 0)]
#               (geneset_111): Parameter containing: [torch.cuda.FloatTensor of size 20x1 (GPU 0)]
#               (geneset_112): Parameter containing: [torch.cuda.FloatTensor of size 51x1 (GPU 0)]
#               (geneset_113): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_114): Parameter containing: [torch.cuda.FloatTensor of size 32x1 (GPU 0)]
#               (geneset_115): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#               (geneset_116): Parameter containing: [torch.cuda.FloatTensor of size 21x1 (GPU 0)]
#               (geneset_117): Parameter containing: [torch.cuda.FloatTensor of size 16x1 (GPU 0)]
#               (geneset_118): Parameter containing: [torch.cuda.FloatTensor of size 10x1 (GPU 0)]
#               (geneset_119): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#               (geneset_12): Parameter containing: [torch.cuda.FloatTensor of size 21x1 (GPU 0)]
#               (geneset_120): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_121): Parameter containing: [torch.cuda.FloatTensor of size 11x1 (GPU 0)]
#               (geneset_122): Parameter containing: [torch.cuda.FloatTensor of size 16x1 (GPU 0)]
#               (geneset_123): Parameter containing: [torch.cuda.FloatTensor of size 10x1 (GPU 0)]
#               (geneset_124): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#               (geneset_125): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_126): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_127): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_128): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (geneset_129): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_13): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_130): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_131): Parameter containing: [torch.cuda.FloatTensor of size 18x1 (GPU 0)]
#               (geneset_14): Parameter containing: [torch.cuda.FloatTensor of size 10x1 (GPU 0)]
#               (geneset_15): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_16): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#               (geneset_17): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (geneset_18): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_19): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_2): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (geneset_20): Parameter containing: [torch.cuda.FloatTensor of size 25x1 (GPU 0)]
#               (geneset_21): Parameter containing: [torch.cuda.FloatTensor of size 15x1 (GPU 0)]
#               (geneset_22): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_23): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_24): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_25): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (geneset_26): Parameter containing: [torch.cuda.FloatTensor of size 10x1 (GPU 0)]
#               (geneset_27): Parameter containing: [torch.cuda.FloatTensor of size 10x1 (GPU 0)]
#               (geneset_28): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_29): Parameter containing: [torch.cuda.FloatTensor of size 45x1 (GPU 0)]
#               (geneset_3): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_30): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_31): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_32): Parameter containing: [torch.cuda.FloatTensor of size 12x1 (GPU 0)]
#               (geneset_33): Parameter containing: [torch.cuda.FloatTensor of size 28x1 (GPU 0)]
#               (geneset_34): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (geneset_35): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (geneset_36): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (geneset_37): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (geneset_38): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_39): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_4): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_40): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#               (geneset_41): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (geneset_42): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_43): Parameter containing: [torch.cuda.FloatTensor of size 9x1 (GPU 0)]
#               (geneset_44): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_45): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_46): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_47): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (geneset_48): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_49): Parameter containing: [torch.cuda.FloatTensor of size 18x1 (GPU 0)]
#               (geneset_5): Parameter containing: [torch.cuda.FloatTensor of size 12x1 (GPU 0)]
#               (geneset_50): Parameter containing: [torch.cuda.FloatTensor of size 15x1 (GPU 0)]
#               (geneset_51): Parameter containing: [torch.cuda.FloatTensor of size 18x1 (GPU 0)]
#               (geneset_52): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_53): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_54): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_55): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_56): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_57): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_58): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_59): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_6): Parameter containing: [torch.cuda.FloatTensor of size 10x1 (GPU 0)]
#               (geneset_60): Parameter containing: [torch.cuda.FloatTensor of size 48x1 (GPU 0)]
#               (geneset_61): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_62): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (geneset_63): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_64): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_65): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_66): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_67): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_68): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_69): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_7): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_70): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_71): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_72): Parameter containing: [torch.cuda.FloatTensor of size 28x1 (GPU 0)]
#               (geneset_73): Parameter containing: [torch.cuda.FloatTensor of size 12x1 (GPU 0)]
#               (geneset_74): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_75): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#               (geneset_76): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_77): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_78): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_79): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_8): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_80): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#               (geneset_81): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_82): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_83): Parameter containing: [torch.cuda.FloatTensor of size 21x1 (GPU 0)]
#               (geneset_84): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_85): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_86): Parameter containing: [torch.cuda.FloatTensor of size 9x1 (GPU 0)]
#               (geneset_87): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_88): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_89): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_9): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (geneset_90): Parameter containing: [torch.cuda.FloatTensor of size 12x1 (GPU 0)]
#               (geneset_91): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (geneset_92): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_93): Parameter containing: [torch.cuda.FloatTensor of size 9x1 (GPU 0)]
#               (geneset_94): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (geneset_95): Parameter containing: [torch.cuda.FloatTensor of size 18x1 (GPU 0)]
#               (geneset_96): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (geneset_97): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (geneset_98): Parameter containing: [torch.cuda.FloatTensor of size 12x1 (GPU 0)]
#               (geneset_99): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#           )
#         )
#       )
#       (geneset_scorer): GeneSetScorer(
#         (genesetscorer): GeneSetScoreLinear(
#           (fc): Linear(in_features=32, out_features=1, bias=True)
#         )
#       )
#     )
#     (cellpathwayprojector): CellPathwayProjector(
#       (cellpathway_aggregator): CellPathwayAggregator(
#         (aggregator): CellPathwayAttentionAggregator(
#           (attention_weights): ParameterDict(
#               (cellpathway_0): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (cellpathway_1): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_10): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (cellpathway_11): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (cellpathway_12): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (cellpathway_13): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (cellpathway_14): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (cellpathway_15): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (cellpathway_16): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_17): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (cellpathway_18): Parameter containing: [torch.cuda.FloatTensor of size 5x1 (GPU 0)]
#               (cellpathway_19): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (cellpathway_2): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_20): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (cellpathway_21): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (cellpathway_22): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_23): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_24): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_25): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_26): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_27): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (cellpathway_28): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (cellpathway_29): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (cellpathway_3): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_30): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_31): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_32): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_33): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_34): Parameter containing: [torch.cuda.FloatTensor of size 1x1 (GPU 0)]
#               (cellpathway_35): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (cellpathway_36): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (cellpathway_37): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (cellpathway_38): Parameter containing: [torch.cuda.FloatTensor of size 7x1 (GPU 0)]
#               (cellpathway_39): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (cellpathway_4): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (cellpathway_40): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (cellpathway_41): Parameter containing: [torch.cuda.FloatTensor of size 8x1 (GPU 0)]
#               (cellpathway_42): Parameter containing: [torch.cuda.FloatTensor of size 3x1 (GPU 0)]
#               (cellpathway_5): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#               (cellpathway_6): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (cellpathway_7): Parameter containing: [torch.cuda.FloatTensor of size 2x1 (GPU 0)]
#               (cellpathway_8): Parameter containing: [torch.cuda.FloatTensor of size 4x1 (GPU 0)]
#               (cellpathway_9): Parameter containing: [torch.cuda.FloatTensor of size 6x1 (GPU 0)]
#           )
#         )
#       )
#     )
#     (patientprojector): GeneSetScorer(
#       (genesetscorer): GeneSetScoreLinear(
#         (fc): Linear(in_features=32, out_features=1, bias=True)
#       )
#     )
#     (cancerprojector): GeneSetScorer(
#       (genesetscorer): GeneSetScoreLinear(
#         (fc): Linear(in_features=32, out_features=1, bias=True)
#       )
#     )
#   )
#   (taskdecoder): ClassDecoder(
#     (input_norm): BatchNorm1d(44, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (lins): ModuleList(
#       (0): Linear(in_features=44, out_features=16, bias=True)
#     )
#     (_batch_norms): ModuleList(
#       (0): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#     (out): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# This process fine-tunes the Compass model on your data and saves the updated model for future use.

# %% [markdown]
# ## 5. Pre-training Compass from Scracth

# %%
# Load the example dataset for pretraining
# We provide sample datasets contain gene expression data for training and testing
# Ensure the data is preprocessed appropriately before use
tcga_train_sample = pd.read_csv('./data/tcga_example_train.tsv', sep='\t', index_col=0)
tcga_test_sample = pd.read_csv('./data/tcga_example_test.tsv', sep='\t', index_col=0)

# %%
# Define pretraining hyperparameters
pt_args = {'lr': 1e-3, 'batch_size': 96, 'epochs': 30, 'seed':42}
pretrainer = PreTrainer(**pt_args)

# Train the model using the provided training and test datasets
# - dfcx_train: Training dataset
# - dfcx_test: Validation dataset to monitor performance
pretrainer.train(dfcx_train=tcga_train_sample,
                 dfcx_test=tcga_test_sample)

# Save the trained pretrainer model for future use
pretrainer.save('./model/my_pretrainer.pt')
# Out:
# Epoch: 1/30 - Train Loss: 0.9092 - Test Loss: 0.8723
# Epoch: 2/30 - Train Loss: 0.8395 - Test Loss: 0.7112
# Epoch: 3/30 - Train Loss: 0.7604 - Test Loss: 0.7278
# Epoch: 4/30 - Train Loss: 0.7532 - Test Loss: 0.7454
# Epoch: 5/30 - Train Loss: 0.7205 - Test Loss: 0.6917
# Epoch: 6/30 - Train Loss: 0.7255 - Test Loss: 0.6076
# Epoch: 7/30 - Train Loss: 0.6778 - Test Loss: 0.7414
# Epoch: 8/30 - Train Loss: 0.6537 - Test Loss: 0.6526
# Epoch: 9/30 - Train Loss: 0.6141 - Test Loss: 0.7231
# Epoch: 10/30 - Train Loss: 0.5916 - Test Loss: 0.4196
# Epoch: 11/30 - Train Loss: 0.5902 - Test Loss: 0.5267
# Epoch: 12/30 - Train Loss: 0.5403 - Test Loss: 0.6389
# Epoch: 13/30 - Train Loss: 0.5512 - Test Loss: 0.5961
# Epoch: 14/30 - Train Loss: 0.5526 - Test Loss: 0.5705
# Epoch: 15/30 - Train Loss: 0.5053 - Test Loss: 0.6384
# Epoch: 16/30 - Train Loss: 0.5142 - Test Loss: 0.3751
# Epoch: 17/30 - Train Loss: 0.4817 - Test Loss: 0.5186
# Epoch: 18/30 - Train Loss: 0.4787 - Test Loss: 0.4119
# Epoch: 19/30 - Train Loss: 0.4581 - Test Loss: 0.4687
# Epoch: 20/30 - Train Loss: 0.4654 - Test Loss: 0.3415
# Epoch: 21/30 - Train Loss: 0.4702 - Test Loss: 0.5015
# Epoch: 22/30 - Train Loss: 0.4270 - Test Loss: 0.2963
# Epoch: 23/30 - Train Loss: 0.4396 - Test Loss: 0.1857
# Epoch: 24/30 - Train Loss: 0.4505 - Test Loss: 0.2163
# Epoch: 25/30 - Train Loss: 0.4462 - Test Loss: 0.4820
# Epoch: 26/30 - Train Loss: 0.4312 - Test Loss: 0.4482
# Epoch: 27/30 - Train Loss: 0.4487 - Test Loss: 0.4063
# Epoch: 28/30 - Train Loss: 0.4093 - Test Loss: 0.3265
# Epoch: 29/30 - Train Loss: 0.4071 - Test Loss: 0.3515
# Epoch: 30/30 - Train Loss: 0.4248 - Test Loss: 0.3010
# Saving final model...
#
# Best validation loss: 0.18566959165036678
#
# Saving best model on epoch: 23
#
# Saving the model to ./model/my_pretrainer.pt

# %% [markdown]
# ## 6. Baseline Methods Usage Examples

# %%
# import the baseline scores
import sys
sys.path.insert(0, '../')
from baseline.immnue_score import immnue_score_methods

# %%
# import the baseline scores
from baseline.immnue_score import immnue_score_methods

# Below is how to extract the features using the baseline methods.
# These features can be used to develop logistic regression model for response prediction
res = []
for k, f in immnue_score_methods.items():
    baseline = f(cancer_type='SKCM', drug_target='PD1')
    s1 = baseline(df_tpm)
    res.append(s1)

pd.concat(res, axis=1).head()
# Out:
# [WARN] The majority(>80%) of genes with positive expression in your inputted data. Please Normalize your data
# [WARN] Start normalizing the input expression profile by: 1. Do the log2(x+1) transformation. 2. Subtract the average across your samples.
#                  PDCD1     CD274     CTLA4   NAG_CD8      CD8B      CD8A  \
# 1_ipiPD1_PRE  0.263034  0.443607  0.584963  0.075813  0.000000  0.333424
# 2_ipiPD1_PRE  0.124328  0.659925  1.042644  0.459469  0.250962  1.769772
# 6_ipiPD1_PRE  0.226509  0.263034  0.378512  0.370453  0.201634  1.427606
# 7_ipiPD1_PRE  0.286881  0.238787  0.545968  0.645404  0.389567  2.448901
# 8_ipiPD1_PRE  0.189034  0.584963  0.978196  0.535612  0.344828  2.010780
#
#                  TBX21     FOXP3     NCAM1      IL10  ...  NAG_Roh_IS  \
# 1_ipiPD1_PRE  0.097611  0.214125  2.678072  1.063503  ...    0.529500
# 2_ipiPD1_PRE  0.201634  0.189034  4.249445  0.604071  ...    0.850548
# 6_ipiPD1_PRE  0.097611  0.176323  2.543496  0.505891  ...    0.707502
# 7_ipiPD1_PRE  0.137504  0.124328  0.948601  0.400538  ...    0.722526
# 8_ipiPD1_PRE  0.056584  0.356144  0.748461  0.925999  ...    0.709227
#
#               NAG_Fehrenbacher_Teff    MAP4K1      TBX3  PCA_Messina_CKS  \
# 1_ipiPD1_PRE               0.255713  2.220330  2.100978        -5.076745
# 2_ipiPD1_PRE               0.292490  3.568032  3.990955        -4.282737
# 6_ipiPD1_PRE               0.490161  2.508429  0.925999        -2.801631
# 7_ipiPD1_PRE               0.695194  1.761285  1.627607        -1.213075
# 8_ipiPD1_PRE               0.736650  2.680324  1.028569        -2.420211
#
#               NAG_Nurmik_CAFs  NAG_Jiang_CTLs  NAG_Jiang_TAMs  NAG_Jiang_Texh  \
# 1_ipiPD1_PRE         0.685883        0.297893        0.688596        0.740698
# 2_ipiPD1_PRE         1.008657        0.423985        0.898566        1.026243
# 6_ipiPD1_PRE         0.754903        0.527356        0.540569        0.660849
# 7_ipiPD1_PRE         0.497768        0.527554        0.472271        0.488581
# 8_ipiPD1_PRE         1.002617        0.582450        0.794207        0.931874
#
#               NAG_Rooney_ICA
# 1_ipiPD1_PRE        0.173749
# 2_ipiPD1_PRE        0.590691
# 6_ipiPD1_PRE        0.459451
# 7_ipiPD1_PRE        0.396062
# 8_ipiPD1_PRE        0.254326
#
# [5 rows x 222 columns]

# %% [markdown]
# ## 7. Additional Information
#
# This section provides detailed information to help you get started with the Compass project. We explain how to generate the necessary inputs from raw FASTQ data and introduce our online web server that supports both prediction and feature extraction using our pre-trained Compass models.
#
# ### Generating Compass Inputs from Raw FASTQ Data
#
# Generating high-quality inputs is crucial for the optimal performance of the Compass models. Our comprehensive [Compass Data Pre-Processing Guide](https://www.immuno-compass.com/help/index.html) walks you through the entire workflow, ensuring that your raw FASTQ data is processed into a robust format ready for accurate predictions and feature extraction.
#
# ### Online Web Server for Prediction and Feature Extraction
#
# To simplify the use of our models, we offer an online web server that enables you to interact directly with the Compass models without local installations. The web server provides two primary functionalities:
#
# - **Prediction:** Submit your processed data to generate model predictions using our [online prediction tool](https://www.immuno-compass.com/predict).
# - **Feature Extraction:** Extract key data attributes with our [feature extraction tool](https://www.immuno-compass.com/extract).
#
# These user-friendly services are designed to streamline your workflow and integrate Compass seamlessly into your analytical processes.
#
# ### Contributing Your Own Compass Models
#
# We welcome contributions from the community. If you have developed a Compass model that can enhance our project, we encourage you to share it. By contributing your model, you help enrich the Compass ecosystem and promote collaborative innovation. For details on how to submit your model, please refer to our contribution guidelines. You can also [join our Slack channel](https://join.slack.com/t/immuno-compass/shared_invite/zt-2znjho738-YZOfLEGLNEH5eH_0W1TmQg) to discuss and collaborate with other users.
#
# ### Citing Our Work
#
# If you use our resources, please cite our work as follows:
#
# Wanxiang Shen, Thinh H. Nguyen, Michelle M. Li, Yepeng Huang, Intae Moon, Daniel Marbach, and Marinka Zitnik. *Cross-cancer AI modeling of immunotherapy response* [J]. medRxiv.
#
# ---
#
# We hope this information helps you make the most of the Compass project. If you have any questions or need further assistance, please do not hesitate to contact our support [team](https://www.immuno-compass.com/contact/index.html).
# itate to contact our support team.
