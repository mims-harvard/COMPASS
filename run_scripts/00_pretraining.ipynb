# %%
# =========================================================
# 2. Install and check COMPASS
# =========================================================
# !pip install immuno-compass==2.0.5
# Out:
# Requirement already satisfied: immuno-compass==2.0.5 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages/immuno_compass-2.0.5-py3.8.egg (2.0.5)
# Requirement already satisfied: torch==1.13.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (1.13.1)
# Requirement already satisfied: torchvision==0.14.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (0.14.1)
# Requirement already satisfied: torchaudio==0.13.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (0.13.1)
# Requirement already satisfied: seaborn==0.12.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (0.12.0)
# Requirement already satisfied: statannotations==0.7.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (0.7.0)
# Requirement already satisfied: einops in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (0.8.1)
# Requirement already satisfied: scikit-learn in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (1.3.2)
# Requirement already satisfied: umap-learn in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (0.5.7)
# Requirement already satisfied: wandb in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (0.22.2)
# Requirement already satisfied: matplotlib in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (3.7.2)
# Requirement already satisfied: comut in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (0.0.3)
# Requirement already satisfied: gseapy in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (1.1.10)
# Requirement already satisfied: tidepy in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (1.3.8)
# Requirement already satisfied: colorcet in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (3.1.0)
# Requirement already satisfied: gdown in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (5.2.0)
# Requirement already satisfied: qnorm in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (0.9.0)
# Requirement already satisfied: openpyxl in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (3.1.5)
# Requirement already satisfied: plotly in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from immuno-compass==2.0.5) (6.3.1)
# Requirement already satisfied: numpy>=1.17 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from seaborn==0.12.0->immuno-compass==2.0.5) (1.22.3)
# Requirement already satisfied: pandas>=0.25 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from seaborn==0.12.0->immuno-compass==2.0.5) (1.4.2)
# Requirement already satisfied: scipy>=1.1.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from statannotations==0.7.0->immuno-compass==2.0.5) (1.10.1)
# Requirement already satisfied: typing-extensions in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from torch==1.13.1->immuno-compass==2.0.5) (4.13.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from torch==1.13.1->immuno-compass==2.0.5) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from torch==1.13.1->immuno-compass==2.0.5) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from torch==1.13.1->immuno-compass==2.0.5) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from torch==1.13.1->immuno-compass==2.0.5) (11.7.99)
# Requirement already satisfied: requests in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from torchvision==0.14.1->immuno-compass==2.0.5) (2.32.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from torchvision==0.14.1->immuno-compass==2.0.5) (10.4.0)
# Requirement already satisfied: setuptools in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->immuno-compass==2.0.5) (75.3.2)
# Requirement already satisfied: wheel in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->immuno-compass==2.0.5) (0.44.0)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from matplotlib->immuno-compass==2.0.5) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from matplotlib->immuno-compass==2.0.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from matplotlib->immuno-compass==2.0.5) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from matplotlib->immuno-compass==2.0.5) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from matplotlib->immuno-compass==2.0.5) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from matplotlib->immuno-compass==2.0.5) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from matplotlib->immuno-compass==2.0.5) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from matplotlib->immuno-compass==2.0.5) (6.4.5)
# Requirement already satisfied: palettable>=3.3.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from comut->immuno-compass==2.0.5) (3.3.3)
# Requirement already satisfied: beautifulsoup4 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from gdown->immuno-compass==2.0.5) (4.14.2)
# Requirement already satisfied: filelock in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from gdown->immuno-compass==2.0.5) (3.16.1)
# Requirement already satisfied: tqdm in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from gdown->immuno-compass==2.0.5) (4.67.1)
# Requirement already satisfied: et-xmlfile in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from openpyxl->immuno-compass==2.0.5) (2.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from plotly->immuno-compass==2.0.5) (1.42.1)
# Requirement already satisfied: numba in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from qnorm->immuno-compass==2.0.5) (0.58.1)
# Requirement already satisfied: joblib>=1.1.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from scikit-learn->immuno-compass==2.0.5) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from scikit-learn->immuno-compass==2.0.5) (3.5.0)
# Requirement already satisfied: pynndescent>=0.5 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from umap-learn->immuno-compass==2.0.5) (0.5.13)
# Requirement already satisfied: click>=8.0.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from wandb->immuno-compass==2.0.5) (8.1.8)
# Requirement already satisfied: eval-type-backport in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from wandb->immuno-compass==2.0.5) (0.2.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from wandb->immuno-compass==2.0.5) (3.1.45)
# Requirement already satisfied: platformdirs in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from wandb->immuno-compass==2.0.5) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.12.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from wandb->immuno-compass==2.0.5) (5.29.5)
# Requirement already satisfied: pydantic<3 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from wandb->immuno-compass==2.0.5) (2.10.6)
# Requirement already satisfied: pyyaml in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from wandb->immuno-compass==2.0.5) (6.0.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from wandb->immuno-compass==2.0.5) (2.42.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb->immuno-compass==2.0.5) (4.0.12)
# Requirement already satisfied: zipp>=3.1.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->immuno-compass==2.0.5) (3.20.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from numba->qnorm->immuno-compass==2.0.5) (0.41.1)
# Requirement already satisfied: importlib-metadata in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from numba->qnorm->immuno-compass==2.0.5) (8.5.0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from pandas>=0.25->seaborn==0.12.0->immuno-compass==2.0.5) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from pydantic<3->wandb->immuno-compass==2.0.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from pydantic<3->wandb->immuno-compass==2.0.5) (2.27.2)
# Requirement already satisfied: six>=1.5 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->immuno-compass==2.0.5) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from requests->torchvision==0.14.1->immuno-compass==2.0.5) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from requests->torchvision==0.14.1->immuno-compass==2.0.5) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from requests->torchvision==0.14.1->immuno-compass==2.0.5) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from requests->torchvision==0.14.1->immuno-compass==2.0.5) (2025.10.5)
# Requirement already satisfied: soupsieve>1.2 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from beautifulsoup4->gdown->immuno-compass==2.0.5) (2.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from requests[socks]->gdown->immuno-compass==2.0.5) (1.7.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /mnt/mamba_envs/envs/compass/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->immuno-compass==2.0.5) (5.0.2)

# %%
import os,sys
os.environ["CUDA_VISIBLE_DEVICES"] = "3"  # Specify which GPU to use

# %%
import compass,random,torch,os
print("COMPASS VERSION:", compass.__version__)
# Out:
# COMPASS VERSION: 2.0.5

# %%
# =========================================================
# 3. Define output directory
# =========================================================
save_dir = './compass_run/PT_v100'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
# =========================================================
# 4. Import core modules
# =========================================================
from compass import loadcompass
from compass import PreTrainer, FineTuner
from compass.tokenizer import CANCER_CODE,TOKENS_SHORT
from compass.utils import plot_performance, score2
import pandas as pd
import numpy as np

get_ipython().run_line_magic('matplotlib', 'inline')

# %%
# =========================================================
# 5. Data loading function
# =========================================================
_GLOBALS = {}

def load_tcga(path):
    """
    Load TCGA transcriptomic and label tables.
    Parameters
    ----------
    path : str
        Path to the folder containing 'TCGA.TPM.TABLE' and 
        'TCGA.PATIENT.PROCESSED.TABLE' files.

    Returns
    -------
    df_tpm : pd.DataFrame
        TPM-normalized gene expression matrix.
    df_label : pd.DataFrame
        Corresponding patient-level metadata.
    """
    if "df_tpm" not in _GLOBALS:
        _GLOBALS["df_tpm"] = pd.read_pickle(os.path.join(path, "TCGA.TPM.TABLE"))
        _GLOBALS["df_label"] = pd.read_pickle(os.path.join(path, "TCGA.PATIENT.TABLE"))
    return _GLOBALS["df_tpm"], _GLOBALS["df_label"]

# %%
# =========================================================
# 6. Prepare data for pretraining
# =========================================================
# Use a subset of genes for faster training (full TCGA gene set is large)

tcga_path = './data/TCGA/'

df_tpm, df_label = load_tcga(tcga_path)

# Encode cancer types numerically
df_cancer = df_label[["cancer_type"]]
dfcx = (
    df_cancer.cancer_type
    .apply(lambda x: x.replace("TCGA-", ""))
    .map(CANCER_CODE)
    .to_frame("cancer_code")
    .join(df_tpm)
)

# Stratified split by cancer type (90% train / 10% test)
test_idx = df_cancer.groupby("cancer_type").apply(
    lambda x: x.sample(frac=0.1, random_state=123).index.tolist()
).sum()
train_idx = df_cancer[~df_cancer.index.isin(test_idx)].index

dfcx_train, dfcx_test = dfcx.loc[train_idx], dfcx.loc[test_idx]
print("Training set:", dfcx_train.shape, "| Test set:", dfcx_test.shape)
# Out:
# Training set: (9166, 2476) | Test set: (1018, 2476)

# %%
# =========================================================
# 7. Define training configuration and Run pretraining
# =========================================================

model_args = {
    'lr': 1e-4,              # Adjust to 1e-4 when using all genes
    'epochs': 20,
    'weight_decay': 1e-10,
    'batch_size': 128,      # Reduce if memory is limited
    'seed': 64,
    'patience': 10,
    'encoder_dropout':0,
    'encoder': 'performer',  # Use performer or transformer encoder for efficient attention
    'batch_correction': 0.6,
}

data_args = {
    'no_augment_prob': 0.2,  # Probability of skipping augmentation 0
    'mask_p_prob': 0.5,      # Probability of masking positive samples
    'jitter_p_std': 0.7,     # Additive noise for feature perturbation 0.8
    'mask_n_prob': 0.0,
    'mask_a_prob': 0.0,
    'jitter_a_std': 0.0,
    'jitter_n_std': 0.0,
}

pretrainer = PreTrainer(**model_args,  work_dir=save_dir)

pretrainer.train(
    dfcx_train=dfcx_train,
    dfcx_test=dfcx_test,
    **data_args)

# Save pretrained model checkpoint
pretrainer.save(f'{save_dir}/pretrainer.pt')
print("Pretraining completed. Model saved to:", 
      f'{save_dir}/pretrainer.pt')
# Out:
# Epoch: 1/20 - Train Loss: 0.8337 - Test Loss: 0.4217
# Epoch: 2/20 - Train Loss: 0.4121 - Test Loss: 0.4066
# Epoch: 3/20 - Train Loss: 0.4048 - Test Loss: 0.4026
# Epoch: 4/20 - Train Loss: 0.4013 - Test Loss: 0.4002
# Epoch: 5/20 - Train Loss: 0.3980 - Test Loss: 0.3959
# Epoch: 6/20 - Train Loss: 0.3939 - Test Loss: 0.3913
# Epoch: 7/20 - Train Loss: 0.3858 - Test Loss: 0.3780
# Epoch: 8/20 - Train Loss: 0.3375 - Test Loss: 0.2525
# Epoch: 9/20 - Train Loss: 0.2225 - Test Loss: 0.2123
# Epoch: 10/20 - Train Loss: 0.2060 - Test Loss: 0.1926
# Epoch: 11/20 - Train Loss: 0.1990 - Test Loss: 0.1971
# Epoch: 12/20 - Train Loss: 0.1988 - Test Loss: 0.1898
# Epoch: 13/20 - Train Loss: 0.1942 - Test Loss: 0.1893
# Epoch: 14/20 - Train Loss: 0.2007 - Test Loss: 0.1959
# Epoch: 15/20 - Train Loss: 0.1913 - Test Loss: 0.1911
# Epoch: 16/20 - Train Loss: 0.1946 - Test Loss: 0.1971
# Epoch: 17/20 - Train Loss: 0.1943 - Test Loss: 0.1912
# Epoch: 18/20 - Train Loss: 0.1907 - Test Loss: 0.1961
# Epoch: 19/20 - Train Loss: 0.1908 - Test Loss: 0.1806
# Epoch: 20/20 - Train Loss: 0.1876 - Test Loss: 0.1801
# Saving final model...
#
# Best validation loss: 0.18006030656397343
#
# Saving best model on epoch: 20
#
# Saving the model to ./compass_run/PT_v100/pretrainer.pt
# Pretraining completed. Model saved to: ./compass_run/PT_v100/pretrainer.pt
